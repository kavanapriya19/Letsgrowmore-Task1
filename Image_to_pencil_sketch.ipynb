# %% [markdown]
# <a href="https://colab.research.google.com/github/kavanapriya19/Letsgrowmore-Task1/blob/main/Image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image = cv2.imread("flower.jpeg")
#image

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[13, 13, 14, ..., 12, 12, 12],
#        [13, 13, 14, ..., 13, 13, 13],
#        [13, 13, 14, ..., 14, 14, 14],
#        ...,
#        [11, 11, 11, ..., 12, 12, 12],
#        [11, 11, 11, ..., 12, 12, 12],
#        [11, 11, 11, ..., 13, 13, 13]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %%
inverted_image = 255 - gray_image
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)
